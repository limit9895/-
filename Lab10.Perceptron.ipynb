# %% [markdown]
# # load ex1 using tf.keras
# ![image.png](attachment:image.png)

# %%
# adaline using keras
from tensorflow.keras import models, layers, optimizers, losses
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.metrics import accuracy_score
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

iris = datasets.load_iris()
X = iris.data
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,shuffle=True)#데이터 분할

model = models.Sequential()
model.add(layers.Dense(units = 16,  activation='relu', input_shape=(4,)))
model.add(layers.Dense(units = 8,  activation='relu'))
model.add(layers.Dense(units = 4,  activation='relu'))
model.add(layers.Dense(units = 3,  activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics = ['acc'])

es = EarlyStopping(monitor='val_loss', mode='min', verbose=0, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=0, save_best_only=True)

model.fit(X_train,y_train,epochs = 1000,  callbacks=[es, mc], batch_size = 8, verbose = 1,validation_split=0.2)
model.evaluate(X_test,y_test)
# Out:
# Epoch 1/1000
# 12/12 [==============================] - 1s 27ms/step - loss: 1.1227 - acc: 0.5208 - val_loss: 1.1161 - val_acc: 0.4167
# Epoch 2/1000
# 12/12 [==============================] - 0s 9ms/step - loss: 1.0489 - acc: 0.5729 - val_loss: 1.0252 - val_acc: 0.5417
# Epoch 3/1000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.9881 - acc: 0.6667 - val_loss: 0.9693 - val_acc: 0.5417
# Epoch 4/1000
# 12/12 [==============================] - 0s 7ms/step - loss: 0.9395 - acc: 0.6667 - val_loss: 0.9221 - val_acc: 0.5000
# Epoch 5/1000
# 12/12 [==============================] - 0s 11ms/step - loss: 0.9097 - acc: 0.5521 - val_loss: 0.8785 - val_acc: 0.7083
# Epoch 6/1000
# 12/12 [==============================] - 0s 7ms/step - loss: 0.8586 - acc: 0.6354 - val_loss: 0.8356 - val_acc: 0.6250
# Epoch 7/1000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.8184 - acc: 0.6146 - val_loss: 0.8024 - val_acc: 0.7083
# Epoch 8/1000
# ...

# %%
len(X_train)
# Out:
# 120

# %%
# test
Xtest_loss,Xtest_acc = model.evaluate(X,T)
print(Xtest_acc)
Ttest = model.predict(X)
print(Ttest)
# Out:
# 1/1 [==============================] - 0s 248ms/step - loss: 0.2507 - acc: 0.7500
# 0.75
# 1/1 [==============================] - 0s 103ms/step
# [[0.50313747 0.49686253]
#  [0.49067515 0.5093248 ]
#  [0.45464486 0.54535514]
#  [0.47180498 0.528195  ]]

# %%
#1번 : 싱글레이어는 리니얼리 인셉퍼러볼(linearly inseparable)을 할수 없다.
#(4)
#머신러닝이 아인건 보충
#인공신경망이 아닌건 중요도
#가우시안 혼합모델은 비선형적인 em기법
#k 민즈 거리기반 거리가 아닌건 중심거리
#서포트 벡터 머신에서는 서포트 백터
#선형변환을 통한 두개는 pca/lda
#의사결정 나무기법에서 분류가는건 정보이득/엔트로피
#지도 학습 비지도 학습 (타겟/결과/라벨) 정답 중 한개
#유전자 알고리즘이루는 기본적인 단계가 아닌건 증식
